# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # import  file ( filename is player_20.csv)

# %%
fifa=pd.read_csv('players_20.csv')

# %%
fifa
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0                       FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 1                           Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3
# 2                Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 3                    Atlético Madrid  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4                        Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# 18273               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2  43+2  45+2
# 18274               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2  44+2  46+2
# 18275         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2  47+2  47+2
# 18276  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2  48+2  48+2
# 18277         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2  48+2  48+2
#
#         lcb    cb   rcb    rb
# 0      52+2  52+2  52+2  63+2
# 1      53+3  53+3  53+3  61+3
# 2      46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN
# 4      49+3  49+3  49+3  61+3
# ...     ...   ...   ...   ...
# 18273  46+2  46+2  46+2  45+2
# 18274  47+2  47+2  47+2  46+2
# 18275  49+2  49+2  49+2  47+2
# 18276  49+2  49+2  49+2  48+2
# 18277  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %% [markdown]
# # Total column and row

# %%
fifa.shape
# Out:
# (18278, 104)

# %% [markdown]
# # print all the category of column

# %%
for col in fifa.columns: print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %% [markdown]
# # Nationality of players belong

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %% [markdown]
# # Top five country players belongs to

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %% [markdown]
# # barchat of top five countries

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),
         list(fifa['nationality'].value_counts()[0:5]) ,color='blue')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # wages of players

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 4              E. Hazard    470000
# 1      Cristiano Ronaldo    405000
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# ...                  ...       ...
# 565         J. Serendero         0
# 1868           M. Mevlja         0
# 14723       R. Fernández         0
# 16356          H. Ivanov         0
# 3053       F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %% [markdown]
# # wages in ascending order

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary
# Out:
#              short_name  wage_eur
# 0              L. Messi    565000
# 4             E. Hazard    470000
# 1     Cristiano Ronaldo    405000
# 22         A. Griezmann    370000
# 5          K. De Bruyne    370000
# ...                 ...       ...
# 1612        A. Zamorado         0
# 1611            A. Vera         0
# 1610        M. Fagundez         0
# 1609          G. Ichazo         0
# 3053      F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %% [markdown]
# # barchat for top 5 players salary

# %%
plt.figure(figsize=(9,5))
plt.bar(list(player_salary['short_name'])[0:5],
       list(player_salary['wage_eur'])[0:5],
       color=['blue','green','red','orange','purple'])
plt.show()

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %% [markdown]
# # Nationality equal to germany

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# 49        178603  https://sofifa.com/player/178603/mats-hummels/...
# ...          ...                                                ...
# 18123     252076  https://sofifa.com/player/252076/lukas-schelle...
# 18156     251856  https://sofifa.com/player/251856/dominik-meise...
# 18186     243537  https://sofifa.com/player/243537/maximilian-br...
# 18191     244043  https://sofifa.com/player/244043/nico-stephan/...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#             short_name              long_name  age         dob  height_cm  \
# 6        M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31            M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36            T. Kroos             Toni Kroos   29  1990-01-04        183
# 37             M. Reus             Marco Reus   30  1989-05-31        180
# 49          M. Hummels          Mats  Hummels   30  1988-12-16        191
# ...                ...                    ...  ...         ...        ...
# 18123  L. Schellenberg     Lukas Schellenberg   18  2000-08-02        183
# 18156        D. Meisel         Dominik Meisel   20  1999-06-29        179
# 18186       M. Breunig     Maximilian Breunig   18  2000-08-14        178
# 18191       N. Stephan           Nico Stephan   18  2000-08-24        191
# 18197       M. Harsman        Matthis Harsman   19  1999-10-04        190
#
#        weight_kg nationality                   club  ...   lwb   ldm   cdm  \
# 6             85     Germany           FC Barcelona  ...   NaN   NaN   NaN
# 31            92     Germany      FC Bayern München  ...   NaN   NaN   NaN
# 36            76     Germany            Real Madrid  ...  75+3  79+3  79+3
# 37            71     Germany      Borussia Dortmund  ...  69+3  65+3  65+3
# 49            94     Germany      Borussia Dortmund  ...  77+3  83+3  83+3
# ...          ...         ...                    ...  ...   ...   ...   ...
# 18123         78     Germany       FC Ingolstadt 04  ...   NaN   NaN   NaN
# 18156         68     Germany  FC Würzburger Kickers  ...  44+2  44+2  44+2
# 18186         67     Germany  FC Würzburger Kickers  ...  37+2  32+2  32+2
# 18191         84     Germany  FC Würzburger Kickers  ...   NaN   NaN   NaN
# 18197         80     Germany              SV Meppen  ...   NaN   NaN   NaN
#
#         rdm   rwb    lb   lcb    cb   rcb    rb
# 6       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 31      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 36     79+3  75+3  72+3  69+3  69+3  69+3  72+3
# 37     65+3  69+3  64+3  55+3  55+3  55+3  64+3
# 49     83+3  77+3  78+3  84+3  84+3  84+3  78+3
# ...     ...   ...   ...   ...   ...   ...   ...
# 18123   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18156  44+2  44+2  44+2  41+2  41+2  41+2  44+2
# 18186  32+2  37+2  35+2  30+2  30+2  30+2  35+2
# 18191   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18197   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1216 rows x 104 columns]

# %% [markdown]
# # Top 5 tall players of germany

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 36          76     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3
# 6           85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# 55          75     Germany    Manchester City  ...  65+2  59+2  59+2  59+2
# 146         80     Germany    Manchester City  ...  76+3  79+3  79+3  79+3
# 70          75     Germany  FC Bayern München  ...  69+3  68+3  68+3  68+3
#
#       rwb    lb   lcb    cb   rcb    rb
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 146  76+3  74+3  72+3  72+3  72+3  74+3
# 70   69+3  67+3  62+3  62+3  62+3  67+3
#
# [5 rows x 104 columns]

# %% [markdown]
# # top 5 players whose salary is highest in germany

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %% [markdown]
# # Top players sort by shooting skills

# %%
player_shooting=fifa[['short_name','shooting','nationality','club','wage_eur']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting nationality               club  wage_eur
# 1    Cristiano Ronaldo      93.0    Portugal           Juventus    405000
# 0             L. Messi      92.0   Argentina       FC Barcelona    565000
# 12             H. Kane      91.0     England  Tottenham Hotspur    220000
# 17           S. Agüero      90.0   Argentina    Manchester City    300000
# 205    F. Quagliarella      89.0       Italy          Sampdoria     46000

# %% [markdown]
# # defending sort by defending skills

# %%
#defending
player_defending=fifa[['short_name','defending','nationality','club','wage_eur']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club  wage_eur
# 16  G. Chiellini       90.0        Italy           Juventus    215000
# 7    V. van Dijk       90.0  Netherlands          Liverpool    200000
# 11  K. Koulibaly       89.0      Senegal             Napoli    150000
# 35      D. Godín       89.0      Uruguay              Inter    135000
# 49    M. Hummels       89.0      Germany  Borussia Dortmund    130000

# %% [markdown]
# # extracting realmadrid players

# %%
real_madrid=fifa[fifa['club']=='Real Madrid']

real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 36     Germany  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
# 46      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3  58+3  54+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 36  69+3  69+3  72+3
# 18  87+3  87+3  82+3
# 46  54+3  54+3  58+3
#
# [5 rows x 104 columns]

# %% [markdown]
# # extracting realmadrid players according to shooting skills

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100         82       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106         75    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4           74     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
# 46          81      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3
# 161         85      Serbia  Real Madrid  ...  55+2  53+2  53+2  53+2  55+2
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# 106  62+3  57+3  57+3  57+3  62+3
# 4    61+3  49+3  49+3  49+3  61+3
# 46   58+3  54+3  54+3  54+3  58+3
# 161  51+2  47+2  47+2  47+2  51+2
#
# [5 rows x 104 columns]

# %% [markdown]
# # realmadrid players sort by nationality

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
